# %%
items_attr = apply_attribute_reasoner(items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 items_attr = apply_attribute_reasoner(items)
#
# NameError: name 'apply_attribute_reasoner' is not defined

# %%
model, item_embeddings, corpus_text = encode_items(items_attr)
liked_ids = list(items_attr["item_id"].sample(10, random_state=0))
items_with_taste, user_taste_vec = add_taste_scores(items_attr, item_embeddings, liked_ids)
items_with_sb = add_smart_buy_index(items_with_taste)
