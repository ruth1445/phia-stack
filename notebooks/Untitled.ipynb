# %%
import os, sys
sys.path.append(os.path.join(os.getcwd(), "..", "src"))

import pandas as pd

from attribute_reasoner import apply_attribute_reasoner
from taste_reasoner import encode_items 
from taste_reasoner import add_taste_scores
from smart_buy import add_smart_buy_index
from ranking import naive_rank, bias_aware_rank
# Out:
# Traceback (most recent call last):
#
#   File /opt/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 7
#     from taste_reasoner import encode_items
#
#   File ~/phia-stack/notebooks/../src/taste_reasoner.py:15
#     lambda r: f\"{r.get('title', '')} {r.get('description', '')} Brand: {r.get('brand', '')}\",
#                 ^
# SyntaxError: unexpected character after line continuation character
